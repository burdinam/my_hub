# %%
#Load the required libraries

import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#Loading data

# %%
df = pd.read_csv("C:/Users/Ark/0_ANALYSIS/DA_projects/hotel_bookings/hotel_bookings.csv", sep=';')

# %%
df.head()
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Hotel                      119390 non-null  object
#  1   Is Canceled                119390 non-null  int64
#  2   Lead Time                  119390 non-null  int64
#  3   arrival full date          119390 non-null  object
#  4   Arrival Date Year          119390 non-null  int64
#  5   Arrival Date Month         119390 non-null  object
#  6   Arrival Date Week Number   119390 non-null  int64
#  7   Arrival Date Day of Month  119390 non-null  int64
#  8   Stays in Weekend nights    119390 non-null  int64
#  9   Stays in week nights       119390 non-null  int64
#  10  stays total nights         119390 non-null  int64
#  11  Adults                     119390 non-null  int64
#  12  Children                   119386 non-null  float64
# ...

# %%
# Reduce column names to lowercase and replace spaces with underscores for ease of use.

# %%
df.columns = [w.strip().lower().replace(' ', '_') for w in df.columns]

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_full_date',
#        'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'stays_total_nights', 'adults', 'children',
#        'babies', 'meal', 'country', 'reserved_room_type', 'assigned_room_type',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
# Top 5 countries by successful bookings

# %%
top_5 = df\
    .query("is_canceled == 0")\
    .groupby("country", as_index=False)\
    .agg({"hotel":"count"})\
    .sort_values("hotel", ascending=False)\
    .rename(columns={"hotel":"total_bookings"})\
    .head()

# %%
top_5
# Out:
#     country  total_bookings
# 125     PRT           21071
# 57      GBR            9676
# 54      FRA            8481
# 50      ESP            6391
# 42      DEU            6069

# %%
# average number of booking nights

# %%
avg_nights = df\
    .query("is_canceled == 0")\
    .groupby("hotel", as_index=False)\
    .agg({"stays_total_nights":"mean"})\
    .sort_values("stays_total_nights", ascending=False)

# %%
avg_nights
# Out:
#           hotel  stays_total_nights
# 1  Resort Hotel            4.142892
# 0    City Hotel            2.923618

# %%
# assigned_room_type and reserved_room_type difference/

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_full_date',
#        'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'stays_total_nights', 'adults', 'children',
#        'babies', 'meal', 'country', 'reserved_room_type', 'assigned_room_type',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df[['reserved_room_type', 'assigned_room_type']]
# Out:
#        reserved_room_type assigned_room_type
# 0                       C                  C
# 1                       C                  C
# 2                       A                  C
# 3                       A                  A
# 4                       A                  A
# ...                   ...                ...
# 119385                  A                  A
# 119386                  E                  E
# 119387                  D                  D
# 119388                  A                  A
# 119389                  A                  A
#
# [119390 rows x 2 columns]

# %%
num_difference = df\
    .query("reserved_room_type != assigned_room_type")\
    .groupby('hotel', as_index = False)\
    .agg({"assigned_room_type":"count"})\
    .sort_values('assigned_room_type', ascending = False)

num_difference
# Out:
#           hotel  assigned_room_type
# 1  Resort Hotel                7725
# 0    City Hotel                7192

# %%
#popular month for booking

# %%
top_months = df\
    .groupby(['arrival_date_month'], as_index = False)\
    .agg({"stays_total_nights":"sum"})\
    .sort_values("stays_total_nights", ascending=False)

top_months.head()
# Out:
#   arrival_date_month  stays_total_nights
# 1             August               54077
# 5               July               49705
# 6               June               39116
# 8                May               38634
# 0              April               37335

# %%
plt.figure(figsize=(12, 8))
ax = sns.countplot(x=df["arrival_date_month"])

# %%
top_3_months_yearly_hotels = df\
    .groupby(['hotel', 'arrival_date_year', 'arrival_date_month'], as_index = False)\
    .agg({"stays_total_nights":"sum"})\
    .sort_values(["hotel", "arrival_date_year", 'stays_total_nights'], ascending=[False, True, False])\
    .groupby(['hotel', "arrival_date_year"])\
    .head(3)

top_3_months_yearly_hotels
# Out:
#            hotel  arrival_date_year arrival_date_month  stays_total_nights
# 31  Resort Hotel               2015          September                8129
# 26  Resort Hotel               2015             August                7652
# 28  Resort Hotel               2015               July                6972
# 33  Resort Hotel               2016             August                8777
# 37  Resort Hotel               2016               July                7891
# 42  Resort Hotel               2016            October                7707
# 48  Resort Hotel               2017               July                9442
# 45  Resort Hotel               2017             August                9257
# 49  Resort Hotel               2017               June                8838
# 5     City Hotel               2015          September                9641
# 4     City Hotel               2015            October                8856
# ...

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=df, x="arrival_date_month", hue="hotel")
# Out:
# <AxesSubplot:xlabel='arrival_date_month', ylabel='count'>

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_full_date',
#        'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'stays_total_nights', 'adults', 'children',
#        'babies', 'meal', 'country', 'reserved_room_type', 'assigned_room_type',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
top_3_months_yearly_hotels_by_cancelation = df\
    .query("is_canceled != 0")\
    .groupby(['hotel', 'arrival_date_year', 'arrival_date_month'], as_index = False)\
    .agg({"stays_total_nights":"sum"})\
    .sort_values(["hotel", "arrival_date_year", 'stays_total_nights'], ascending=[False, True, False])\
    .groupby(['hotel', "arrival_date_year"])\
    .head(3)

top_3_months_yearly_hotels_by_cancelation
# Out:
#            hotel  arrival_date_year arrival_date_month  stays_total_nights
# 31  Resort Hotel               2015          September                2565
# 26  Resort Hotel               2015             August                2044
# 30  Resort Hotel               2015            October                1827
# 33  Resort Hotel               2016             August                3103
# 37  Resort Hotel               2016               July                2551
# 42  Resort Hotel               2016            October                2418
# 48  Resort Hotel               2017               July                3845
# 45  Resort Hotel               2017             August                3693
# 49  Resort Hotel               2017               June                3513
# 5     City Hotel               2015          September                4160
# 4     City Hotel               2015            October                3286
# ...

# %%
# adults, children и babies sum, means

# %%
df[['adults', 'children', 'babies']].sum()
# Out:
# adults      221636.0
# children     12403.0
# babies         949.0
# dtype: float64

# %%
df[['adults', 'children', 'babies']].mean()
# Out:
# adults      1.856403
# children    0.103890
# babies      0.007949
# dtype: float64

# %%
# children and babies can be combined

# %%
df['total_kids'] = df.children + df.babies

# %%
# Where do people with kids go?

# %%
hotels_w_kids = df\
    .groupby('hotel', as_index=False)\
    .agg({"total_kids":"mean"})
hotels_w_kids
# Out:
#           hotel  total_kids
# 0    City Hotel    0.096311
# 1  Resort Hotel    0.142586

# %%
# Who did the most booking cancellations? w/o kids?

# %%
df['has_kids'] = df['total_kids'] != 0

# %%
df.groupby(['has_kids'])['is_canceled'].value_counts(normalize=True)
# Out:
# has_kids  is_canceled
# False     0              0.627810
#           1              0.372190
# True      0              0.650493
#           1              0.349507
# Name: is_canceled, dtype: float64

# %%
# figures are much the same.
